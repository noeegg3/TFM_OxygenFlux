# %% [markdown]
# # NOTAS REUNIÓN
#
# --> para cada ventana probar varios
# --> puede haber desblaanceado (no se puede trabajar con accuracy)
# --> tsfresh efficient
# --> varios clasificadores en sklearn bayesianos, decision tree basico
# --> mini busqueda de parametros
# --> cual esel mejor
# --> hacer dataset de reultados para hacer comparativa de gráficas
#
#
# --> preguntar Carmen solo dos clases
# --> análisis de como de balanceadas están las clases en función de las clases que se tengan
#
#
# --> saber si hay mucho oleaje con el modelo y sin usar altura de ola, solo con presión, por ejemplo
# --> altura de ola: etiqueta (del mínimo al maximo)
#
# hacer graficas con 3 oleajes, por ejemplo.
#
# predecir altura de ola sacandola de los modelos.
#
# sacar importancia características con randomforest, con esto sabemos qué características son las más importantes
#
# ### IMPORTANTE: hacer comparativa con varios tamaños de ventana
# ### IMPORTANTE: hacer CLASIFICACIÓN con modelo sin tener tamaño ola y predecir altura, y después saber variables más importantes
#
# ### IMPORTANTE: doble limpieza

# %% [markdown]
# # REVISAR UMBRAL DE VELOCIDAD MÍNIMA

# %% [markdown]
# Hacer que la limpieza solo interpole y marque ventanas con outliers, pero que no borre ni ponga nan
